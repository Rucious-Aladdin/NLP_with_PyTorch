# %%
#2-1 corpus, token, type

# text with metadata = sample or data point
# collection of samples = dataset = corpus

#일반적인 언어의 토큰화 -> 공백 및 구두점으로 구분
#터키어와 같은 교착어 -> 바이트스트림으로 해결

# %%
#spacy 토크나이저
import spacy
nlp = spacy.load("en_core_web_sm") # spacy.load("en") -> spacy.load("en_core_web_sm")
text = "Mary, don't slap the green witch"
print([str(token) for token in nlp(text.lower())])
# Out:
# ['mary', ',', 'do', "n't", 'slap', 'the', 'green', 'witch']

# %%
from nltk.tokenize import TweetTokenizer
# 문자열 앞에 u --> unicode 문자열
tweet = u"Snow White and the Seven Degrees#MakeAMovieCold@midnight:-)"
tokenizer = TweetTokenizer()
print(tokenizer.tokenize(tweet.lower()))
# Out:
# ['snow', 'white', 'and', 'the', 'seven', 'degrees', '#makeamoviecold', '@midnight', ':-)']
