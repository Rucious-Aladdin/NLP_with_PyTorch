# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
from argparse import Namespace
import nltk
from nltk.tokenize import word_tokenize
nltk.download("punkt")
import numpy as np
import pandas as pd
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# !mkdir /content/drive/MyDrive/Github_NLP/NLP_with_PyTorch/Chapter8_Seq_Modeling_Advanced/data
# !wget https://git.io/JqQBE -O data/download.py
# !wget https://git.io/JqQB7 -O data/get-all-data.sh
# !chmod 755 /content/drive/MyDrive/Github_NLP/NLP_with_PyTorch/Chapter8_Seq_Modeling_Advanced/data/get-all-data.sh
# %cd  /content/drive/MyDrive/Github_NLP/NLP_with_PyTorch/Chapter8_Seq_Modeling_Advanced/data
# !./get-all-data.sh
# %cd ..
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/Github_NLP/NLP_with_PyTorch/Chapter8_Seq_Modeling_Advanced/data’: File exists
# --2024-03-20 11:09:07--  https://git.io/JqQBE
# Resolving git.io (git.io)... 140.82.114.22
# Connecting to git.io (git.io)|140.82.114.22|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://raw.githubusercontent.com/rickiepark/nlp-with-pytorch/main/chapter_8/8_5_NMT/data/download.py [following]
# --2024-03-20 11:09:07--  https://raw.githubusercontent.com/rickiepark/nlp-with-pytorch/main/chapter_8/8_5_NMT/data/download.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1572 (1.5K) [text/plain]
# Saving to: ‘data/download.py’
#
# data/download.py    100%[===================>]   1.54K  --.-KB/s    in 0s
#
# 2024-03-20 11:09:07 (9.06 MB/s) - ‘data/download.py’ saved [1572/1572]
#
# --2024-03-20 11:09:07--  https://git.io/JqQB7
# Resolving git.io (git.io)... 140.82.114.22
# Connecting to git.io (git.io)|140.82.114.22|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://raw.githubusercontent.com/rickiepark/nlp-with-pytorch/main/chapter_8/8_5_NMT/data/get-all-data.sh [following]
# --2024-03-20 11:09:07--  https://raw.githubusercontent.com/rickiepark/nlp-with-pytorch/main/chapter_8/8_5_NMT/data/get-all-data.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 460 [text/plain]
# Saving to: ‘data/get-all-data.sh’
#
# data/get-all-data.s 100%[===================>]     460  --.-KB/s    in 0s
#
# 2024-03-20 11:09:07 (18.2 MB/s) - ‘data/get-all-data.sh’ saved [460/460]
#
# /content/drive/MyDrive/Github_NLP/NLP_with_PyTorch/Chapter8_Seq_Modeling_Advanced/data
# /content/drive/MyDrive/Github_NLP/NLP_with_PyTorch/Chapter8_Seq_Modeling_Advanced

# %%
args = Namespace(
    source_data_path="/content/drive/MyDrive/Github_NLP/NLP_with_PyTorch/Chapter8_Seq_Modeling_Advanced/data/nmt/eng-fra.txt",
    output_data_path="/content/drive/MyDrive/Github_NLP/NLP_with_PyTorch/Chapter8_Seq_Modeling_Advanced/data/nmt/mytest_eng_fra.csv",
    perc_train=0.7,
    perc_val=0.15,
    perc_test=0.15,
    seed=1337
)
assert args.perc_test > 0 and (args.perc_test + args.perc_val + args.perc_train == 1.0)

# %%
with open(args.source_data_path) as fp:
  lines = fp.readlines()

lines = [line.replace("\n", "").lower().split("\t") for line in lines]

# %%
data = []
for english_sentence, french_sentence in lines:
  data.append({
      "english_tokens": word_tokenize(english_sentence, language="english"),
      "french_tokens" : word_tokenize(french_sentence, language="french")
  })

# %%
for l in data[3000:3050]:
  print(l)
# Out:
# {'english_tokens': ['i', 'have', 'to', 'go', '.'], 'french_tokens': ['il', 'me', 'faut', 'partir', '.']}
# {'english_tokens': ['i', 'have', 'to', 'go', '.'], 'french_tokens': ['il', 'me', 'faut', "m'en", 'aller', '.']}
# {'english_tokens': ['i', 'have', 'to', 'go', '.'], 'french_tokens': ['je', 'dois', 'partir', '.']}
# {'english_tokens': ['i', 'have', 'to', 'go', '.'], 'french_tokens': ['je', 'dois', "m'en", 'aller', '.']}
# {'english_tokens': ['i', 'hear', 'music', '.'], 'french_tokens': ["j'entends", 'de', 'la', 'musique', '.']}
# {'english_tokens': ['i', 'heard', 'that', '.'], 'french_tokens': ["j'ai", 'entendu', 'ça', '.']}
# {'english_tokens': ['i', 'helped', 'out', '.'], 'french_tokens': ["j'ai", 'donné', 'un', 'coup', 'de', 'main', '.']}
# {'english_tokens': ['i', 'honor', 'that', '.'], 'french_tokens': ["j'honore", 'cela', '.']}
# {'english_tokens': ['i', 'hugged', 'her', '.'], 'french_tokens': ['je', "l'étreignis", '.']}
# {'english_tokens': ['i', 'improvised', '.'], 'french_tokens': ["j'ai", 'improvisé', '.']}
# {'english_tokens': ['i', 'just', 'moved', '.'], 'french_tokens': ['je', 'viens', 'juste', 'de', 'déménager', '.']}
# {'english_tokens': ['i', 'just', 'moved', '.'], 'french_tokens': ['je', 'viens', 'juste', 'de', 'bouger', '.']}
# {'english_tokens': ['i', 'just', 'moved', '.'], 'french_tokens': ['je', 'viens', "d'être", 'muté', '.']}
# {'english_tokens': ['i', 'keep', 'a', 'dog', '.'], 'french_tokens': ["j'élève", 'un', 'chien', '.']}
# {'english_tokens': ['i', 'kissed', 'tom', '.'], 'french_tokens': ["j'ai", 'embrassé', 'tom', '.']}
# {'english_tokens': ['i', 'like', 'china', '.'], 'french_tokens': ["j'aime", 'la', 'chine', '.']}
# {'english_tokens': ['i', 'like', 'r', '&', 'b', '.'], 'french_tokens': ["j'aime", 'le', 'r', '&', 'b', '.']}
# {'english_tokens': ['i', 'like', 'bread', '.'], 'french_tokens': ["j'aime", 'le', 'pain', '.']}
# {'english_tokens': ['i', 'like', 'chess', '.'], 'french_tokens': ["j'apprécie", 'les', 'échecs', '.']}
# {'english_tokens': ['i', 'like', 'fruit', '.'], 'french_tokens': ["j'aime", 'les', 'fruits', '.']}
# {'english_tokens': ['i', 'like', 'girls', '.'], 'french_tokens': ["j'aime", 'les', 'filles', '.']}
# {'english_tokens': ['i', 'like', 'honey', '.'], 'french_tokens': ["j'aime", 'le', 'miel', '.']}
# {'english_tokens': ['i', 'like', 'music', '.'], 'french_tokens': ["j'aime", 'la', 'musique', '.']}
# {'english_tokens': ['i', 'like', 'opera', '.'], 'french_tokens': ["j'apprécie", "l'opéra", '.']}
# {'english_tokens': ['i', 'like', 'sushi', '.'], 'french_tokens': ["j'aime", 'les', 'sushis', '.']}
# {'english_tokens': ['i', 'like', 'these', '.'], 'french_tokens': ["j'aime", 'ceux-ci', '.']}
# {'english_tokens': ['i', 'like', 'these', '.'], 'french_tokens': ["j'aime", 'celles-ci', '.']}
# {'english_tokens': ['i', 'like', 'women', '.'], 'french_tokens': ["j'apprécie", 'les', 'femmes', '.']}
# {'english_tokens': ['i', 'like', 'women', '.'], 'french_tokens': ["j'aime", 'les', 'femmes', '.']}
# {'english_tokens': ['i', 'love', 'books', '.'], 'french_tokens': ["j'adore", 'les', 'livres', '.']}
# {'english_tokens': ['i', 'love', 'bread', '.'], 'french_tokens': ["j'adore", 'le', 'pain', '.']}
# {'english_tokens': ['i', 'love', 'games', '.'], 'french_tokens': ["j'adore", 'les', 'jeux', '.']}
# {'english_tokens': ['i', 'love', 'jokes', '.'], 'french_tokens': ["j'adore", 'les', 'blagues', '.']}
# {'english_tokens': ['i', 'love', 'jokes', '.'], 'french_tokens': ["j'adore", 'les', 'plaisanteries', '.']}
# {'english_tokens': ['i', 'love', 'music', '.'], 'french_tokens': ["j'adore", 'la', 'musique', '.']}
# {'english_tokens': ['i', 'love', 'music', '.'], 'french_tokens': ["j'aime", 'beaucoup', 'la', 'musique', '.']}
# {'english_tokens': ['i', 'love', 'trips', '.'], 'french_tokens': ["j'aime", 'les', 'voyages', '.']}
# {'english_tokens': ['i', 'loved', 'that', '.'], 'french_tokens': ["j'adorais", 'ça', '.']}
# {'english_tokens': ['i', 'loved', 'that', '.'], 'french_tokens': ["j'ai", 'adoré', 'ça', '.']}
# {'english_tokens': ['i', 'made', 'a', 'bet', '.'], 'french_tokens': ["j'ai", 'effectué', 'un', 'pari', '.']}
# {'english_tokens': ['i', 'made', 'plans', '.'], 'french_tokens': ["j'ai", 'élaboré', 'des', 'plans', '.']}
# {'english_tokens': ['i', 'made', 'plans', '.'], 'french_tokens': ["j'ai", 'fait', 'des', 'projets', '.']}
# {'english_tokens': ['i', 'made', 'these', '.'], 'french_tokens': ["j'ai", 'fait', 'ceux-ci', '.']}
# {'english_tokens': ['i', 'made', 'these', '.'], 'french_tokens': ["j'ai", 'fait', 'celles-ci', '.']}
# {'english_tokens': ['i', 'made', 'these', '.'], 'french_tokens': ["j'ai", 'confectionné', 'ceux-ci', '.']}
# {'english_tokens': ['i', 'might', 'stay', '.'], 'french_tokens': ['il', 'se', 'pourrait', 'que', 'je', 'reste', '.']}
# {'english_tokens': ['i', 'missed', 'you', '.'], 'french_tokens': ['tu', "m'as", 'manqué', '.']}
# {'english_tokens': ['i', 'must', 'hurry', '.'], 'french_tokens': ['je', 'dois', 'me', 'grouiller', '.']}
# {'english_tokens': ['i', 'must', 'hurry', '.'], 'french_tokens': ['je', 'dois', 'me', 'dépêcher', '.']}
# {'english_tokens': ['i', 'must', 'hurry', '.'], 'french_tokens': ['je', 'dois', 'me', 'hâter', '.']}

# %%
filter_phrases = (
    ("i", "am"), ("i", "'m"),
    ("he", "is"), ("he", "'s"),
    ("she", "is"), ("she", "'s"),
    ("you", "are"), ("you", "'re"),
    ("we", "are"), ("we", "'re"),
    ("they", "are"), ("they", "'re")
)

# %%
data_subset = {
    phrase: [] for phrase in filter_phrases
}

for datum in data:
  key = tuple(datum["english_tokens"][:2])
  if key in data_subset:
    data_subset[key].append(datum)

# %%
counts = {k :len(v) for k, v in data_subset .items()}
counts, sum(counts.values())
# Out:
# ({('i', 'am'): 805,
#   ('i', "'m"): 4760,
#   ('he', 'is'): 1069,
#   ('he', "'s"): 787,
#   ('she', 'is'): 504,
#   ('she', "'s"): 316,
#   ('you', 'are'): 449,
#   ('you', "'re"): 2474,
#   ('we', 'are'): 181,
#   ('we', "'re"): 1053,
#   ('they', 'are'): 194,
#   ('they', "'re"): 470},
#  13062)

# %%
np.random.seed(args.seed)

dataset_stage3 = []
for phrase, datum_list in sorted(data_subset.items()):
  np.random.shuffle(datum_list)
  n_train = int(len(datum_list) * args.perc_train)
  n_val = int(len(datum_list) * args.perc_val)

  for datum in datum_list[:n_train]:
    datum["split"] = "train"
  for datum in datum_list[n_train:n_train+n_val]:
    datum["split"] = "val"
  for datum in datum_list[n_train+n_val:]:
    datum["split"] = "test"

  dataset_stage3.extend(datum_list)

# %%
for l in dataset_stage3[:20]:
  print("english tokens:", str(l["english_tokens"]))
  print("french tokens: ", str(l["french_tokens"]))
  print("split:", str(l["split"]))
  print()
# Out:
# english tokens: ['he', "'s", 'the', 'cutest', 'boy', 'in', 'town', '.']
# french tokens:  ["c'est", 'le', 'garçon', 'le', 'plus', 'mignon', 'en', 'ville', '.']
# split: train
#
# english tokens: ['he', "'s", 'a', 'nonsmoker', '.']
# french tokens:  ['il', 'est', 'non-fumeur', '.']
# split: train
#
# english tokens: ['he', "'s", 'smarter', 'than', 'me', '.']
# french tokens:  ['il', 'est', 'plus', 'intelligent', 'que', 'moi', '.']
# split: train
#
# english tokens: ['he', "'s", 'a', 'lovely', 'young', 'man', '.']
# french tokens:  ["c'est", 'un', 'adorable', 'jeune', 'homme', '.']
# split: train
#
# english tokens: ['he', "'s", 'three', 'years', 'older', 'than', 'me', '.']
# french tokens:  ['il', 'a', 'trois', 'ans', 'de', 'plus', 'que', 'moi', '.']
# split: train
#
# english tokens: ['he', "'s", 'washing', 'your', 'car', '.']
# french tokens:  ['il', 'lave', 'votre', 'voiture', '.']
# split: train
#
# english tokens: ['he', "'s", 'your', 'typical', 'workaholic', '.']
# french tokens:  ['il', 'est', "l'archétype", 'du', 'bourreau', 'de', 'travail', ',', 'tel', 'que', 'tu', 'te', "l'imagines", '.']
# split: train
#
# english tokens: ['he', "'s", 'waiting', 'for', 'you', 'at', 'home', '.']
# french tokens:  ['il', "t'attend", 'chez', 'nous', '.']
# split: train
#
# english tokens: ['he', "'s", 'a', 'historian', '.']
# french tokens:  ['il', 'est', 'historien', '.']
# split: train
#
# english tokens: ['he', "'s", 'studying', '.']
# french tokens:  ['il', 'étudie', '.']
# split: train
#
# english tokens: ['he', "'s", 'down', 'to', 'earth', '.']
# french tokens:  ['il', 'est', 'concret', '.']
# split: train
#
# english tokens: ['he', "'s", 'starting', 'to', 'feel', 'desperate', '.']
# french tokens:  ['il', 'commence', 'à', 'se', 'sentir', 'désespéré', '.']
# split: train
#
# english tokens: ['he', "'s", 'sketching', 'an', 'apple', '.']
# french tokens:  ['il', 'est', 'en', 'train', 'de', 'dessiner', 'une', 'pomme', '.']
# split: train
#
# english tokens: ['he', "'s", 'worried', 'about', 'the', 'result', '.']
# french tokens:  ['il', 'se', 'préoccupe', 'du', 'résultat', '.']
# split: train
#
# english tokens: ['he', "'s", 'out', 'of', 'town', '.']
# french tokens:  ['il', 'ne', 'se', 'trouve', 'pas', 'en', 'ville', '.']
# split: train
#
# english tokens: ['he', "'s", 'a', 'freelance', 'journalist', '.']
# french tokens:  ["c'est", 'un', 'pigiste', '.']
# split: train
#
# english tokens: ['he', "'s", 'afraid', 'of', 'snakes', '.']
# french tokens:  ['il', 'a', 'peur', 'des', 'serpents', '.']
# split: train
#
# english tokens: ['he', "'s", 'nothing', 'more', 'than', 'a', 'common', 'thug', '.']
# french tokens:  ['il', "n'est", 'rien', "d'autre", "qu'un", 'vulgaire', 'voyou', '.']
# split: train
#
# english tokens: ['he', "'s", 'a', 'journalist', '.']
# french tokens:  ['il', 'est', 'journaliste', '.']
# split: train
#
# english tokens: ['he', "'s", 'waiting', 'for', 'the', 'train', 'to', 'leave', '.']
# french tokens:  ['il', 'attend', 'que', 'le', 'train', 'parte', '.']
# split: train

# %%
for datum in dataset_stage3:
  datum["source_language"] = " ".join(datum.pop("english_tokens"))
  datum["target_language"] = " ".join(datum.pop("french_tokens"))

# %%
nmt_df = pd.DataFrame(dataset_stage3)

# %%
nmt_df.groupby("split").count()
# Out:
#        source_language  target_language
# split
# test              1969             1969
# train             9138             9138
# val               1955             1955

# %%
nmt_df.loc[nmt_df.split == "train"].head()
# Out:
#    split                    source_language  \
# 0  train     he 's the cutest boy in town .
# 1  train                he 's a nonsmoker .
# 2  train            he 's smarter than me .
# 3  train         he 's a lovely young man .
# 4  train  he 's three years older than me .
#
#                              target_language
# 0  c'est le garçon le plus mignon en ville .
# 1                        il est non-fumeur .
# 2          il est plus intelligent que moi .
# 3            c'est un adorable jeune homme .
# 4           il a trois ans de plus que moi .

# %%
nmt_df.loc[nmt_df.split == "val"].head()
# Out:
#     split          source_language                      target_language
# 550   val        he 's all right .                         il va bien .
# 551   val  he 's in grave danger .             il est en danger grave .
# 552   val  he 's making progress .                il fait des progrès .
# 553   val   he 's about to leave .  il est sur le point de s'en aller .
# 554   val  he 's my half-brother .              il est mon demi-frère .

# %%
nmt_df.loc[nmt_df.split == "test"].head()
# Out:
#     split                        source_language  \
# 668  test              he 's a man of his word .
# 669  test                  he 's not available .
# 670  test                 he 's in the kitchen .
# 671  test  he 's busy and ca n't meet with you .
# 672  test              he 's a talented writer .
#
#                                        target_language
# 668                         c'est un homme de parole .
# 669                          il n'est pas disponible .
# 670                           il est dans la cuisine .
# 671  puisqu'il est occupé il ne peut pas vous renco...
# 672                      c'est un écrivain de talent .

# %%
nmt_df.to_csv(args.output_data_path)
